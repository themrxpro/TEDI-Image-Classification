# %%
import tensorflow as tf
import pickle

model = tf.keras.models.load_model('./model_2_0')

history = pickle.load(open('./model_2_0_trainHistory', "rb"))

# %%
print(history.keys())
print(len(history['accuracy']))
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 20

# %%
from matplotlib import pyplot as plt

plt.title('TITLE')
plt.plot(   range(1,21),    history['val_accuracy'],
            range(1,21),    history['accuracy']
            )

plt.legend(['val_accuracy','accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.title('TITLE')
plt.plot(   range(1,21),    history['val_loss'],
            range(1,21),    history['loss']
            )
            
plt.legend(['val_loss','loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history
# Out:
# {'loss': [0.6868387460708618,
#   0.6303225755691528,
#   0.6004459261894226,
#   0.5685874819755554,
#   0.540083110332489,
#   0.5232946872711182,
#   0.506601870059967,
#   0.48978927731513977,
#   0.484287291765213,
#   0.45613807439804077,
#   0.4491245448589325,
#   0.423506498336792,
#   0.4068966209888458,
#   0.39174655079841614,
#   0.37421688437461853,
#   0.3605557680130005,
#   0.34360194206237793,
#   0.33655253052711487,
#   0.3133402466773987,
#   0.2921653687953949],
#  'accuracy': [0.5835733413696289,
#   0.6410133242607117,
#   0.6727466583251953,
#   0.7062399983406067,
#   0.7293866872787476,
#   0.7444800138473511,
#   0.7555733323097229,
#   0.7667733430862427,
#   0.7688533067703247,
#   0.7883733510971069,
#   0.7900800108909607,
#   0.8071466684341431,
#   0.8201599717140198,
#   0.8275200128555298,
#   0.8363199830055237,
#   0.8436800241470337,
#   0.8526399731636047,
#   0.8553599715232849,
#   0.867306649684906,
#   0.8801066875457764],
# ...
